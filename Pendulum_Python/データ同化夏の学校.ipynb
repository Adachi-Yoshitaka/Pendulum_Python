# %%
# %run -i pendulum.py

# %%
# %run -i runEnKF.py
# Out:
# t = 60
# t = 120
# t = 180
# t = 240
# t = 300
# t = 360
# t = 420
# t = 480
# t = 540
# t = 600
# t = 660
# t = 720
# t = 780
# t = 840
# t = 900
# t = 960
# t = 1020
# t = 1080
# t = 1140
# t = 1200
# t = 1260
# t = 1320
# t = 1380
# t = 1440
# t = 1500
# t = 1560
# t = 1620
# t = 1680
# t = 1740
# t = 1800
# t = 1860
# t = 1920
# t = 1980
# t = 2040
# t = 2100
# t = 2160
# t = 2220
# t = 2280
# t = 2340
# t = 2400
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\Pendulum_Python\runEnKF.py in <module>()
#      64 plt.plot( xtruth[:,0], xtruth[:,2], color='LightGreen' )
#      65
# ---> 66 plt.plot( xtruth[:,0], xest[:,0], color='b' )
#      67 plt.plot( xtruth[:,0], xest[:,1], color='g' )
#      68
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# ...

# %%
# %run -i pendulum_adj.py

# %%
# %run -i run4DVAR.py
# Out:
# Iter 13: J=0.031891432812436456
# [-0.00434517  0.17436816]
# [ 0.94299513 -0.05649282]
# Iter 29: J=1.8247954105129542
# [ 0.98874746 -0.07546913]
# [0.11284129 0.02456042]
# Iter 29: J=1.048695516242499
# [0.07263388 0.03518801]
# [ 0.60630243 -0.05454752]
# Iter 0: J=0.7806754734047417
# [ 0.6072618  -0.05430356]
# [-1.15696499 -0.11125076]
# Iter 29: J=1.3241134341213612
# [-1.10817442 -0.14811562]
# [-0.46648838  0.18638549]
# Iter 9: J=0.010689957873861487
# [-0.4662156   0.13671835]
# [ 0.23989507 -0.01978768]
# Iter 4: J=0.07206279285888659
# [ 0.24128228 -0.0282903 ]
# [0.43306368 0.08805419]
# Iter 0: J=0.047902759215633806
# [0.43327665 0.08787211]
# [ 0.85456029 -0.07354108]
# Iter 8: J=0.3778195776746556
# [ 0.86044917 -0.10704223]
# [-0.56788398 -0.05511946]
# Iter 8: J=0.161133611083269
# [-0.56285487 -0.08234774]
# [-0.49137384  0.04354423]
# Iter 7: J=0.09520815348090822
# [-0.49361328  0.06590371]
# [-0.52229395 -0.04347779]
# Iter 6: J=0.7282177900066871
# ...
